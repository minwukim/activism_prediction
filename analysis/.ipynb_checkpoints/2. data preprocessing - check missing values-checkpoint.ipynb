# %% [markdown]
# # Data Preprocessing - Check Missing Values for Each Row and Each Column

# %% [markdown]
# In this notebook, we attempt to check the missing values for each data and each column.

# %% [markdown]
# ## 0. Data & Package Import

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../database/2016-2022.csv')
# Out:
# /var/folders/kw/6hnl881s2p9701b42gpjt_pr0000gn/T/ipykernel_19634/1726423081.py:1: DtypeWarning: Columns (7,8,64,66,73,74,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../database/2016-2022.csv')

# %%
df.head()
# Out:
#    year                  ID    ticker                    company_name  \
# 0  2016  1518855D US Equity  1518855D  Yahoo! Inc - Set up for Fundam
# 1  2016  1539941D UN Equity  1539941D              Spectra Energy LLC
# 2  2016  1556442D UA Equity  1556442D                     GigPeak Inc
# 3  2016  1624831D UN Equity  1624831D           TIAA FSB Holdings Inc
# 4  2016  1627503D UN Equity  1627503D          Colony Capital Inc/Old
#
#      market_cap                     bic_level_2                bic_level_3  \
# 0  3.690000e+10                           Media  Internet Media & Services
# 1  2.880000e+10                       Oil & Gas        Oil & Gas Producers
# 2  1.710000e+08  Tech Hardware & Semiconductors             Semiconductors
# 3  2.460000e+09                         Banking                    Banking
# 4  2.310000e+09              Financial Services          Specialty Finance
#
#   unequal_voting ceo_tenure ipo_date  ...  dividend_to_common  \
# 0            0.0        9.0      NaN  ...        0.000000e+00
# 1            0.0       4.25      NaN  ...        1.090000e+09
# 2            0.0    9.66667      NaN  ...        0.000000e+00
# 3            0.0       20.0      NaN  ...        3.004690e+07
# 4            1.0    7.33333      NaN  ...        1.810000e+08
#
#    dividend_to_preferred  dividend_payout_ratio  \
# 0                    0.0               -0.00000
# 1                    NaN              345.47300
# 2                    0.0                0.00000
# 3             10125000.0               24.70332
# 4             48200000.0              176.07490
#
#    total_compensation_to_executives  total_compensation_to_board_members  \
# 0                         8510000.0                            1150000.0
# 1                        23471757.0                          3602528.659
# 2                       126000000.0                                  NaN
# 3                         8194543.0                            1068000.0
# 4                        55521900.0                            1970000.0
#
#    institution_ownership_percertage  asset_to_equity  cash_conversion_cycle  \
# 0                               NaN             1.57                    NaN
# 1                              79.1             3.00                   14.6
# 2                              41.5             1.30                  173.0
# 3                              89.0            15.10                    NaN
# 4                             118.0             1.80                    NaN
#
#    final_shares_outstanding  targeted
# 0               954000000.0         0
# 1               702000000.0         0
# 2                67700000.0         0
# 3               127000000.0         0
# 4               113000000.0         0
#
# [5 rows x 80 columns]

# %% [markdown]
# ## 1. Check the missing values for each column (fields)

# %%
# Group by 'year' and calculate missing values for each year
grouped_missing = df.groupby('year').apply(lambda x: x.isnull().sum())
grouped_missing_pct = df.groupby('year').apply(lambda x: (x.isnull().mean() * 100))

# Rename columns for clarity
missing_data = {}
for year in range(2016, 2023):
    missing_data[f'{year}_count'] = grouped_missing.loc[year]
    missing_data[f'{year}_pct'] = grouped_missing_pct.loc[year]

# Calculate missing values for the entire dataframe
missing_data['total_count'] = df.isnull().sum()
missing_data['total_pct'] = df.isnull().mean() * 100

# Create the desired dataframe
df_missing = pd.DataFrame(missing_data)

# %%
df_missing.head()
# Out:
#               2016_count  2016_pct  2017_count  2017_pct  2018_count  \
# year                   0  0.000000           0  0.000000           0
# ID                     0  0.000000           0  0.000000           0
# ticker                 0  0.000000           1  0.037951           0
# company_name           0  0.000000           0  0.000000           0
# market_cap             4  0.146735           4  0.151803           4
#
#               2018_pct  2019_count  2019_pct  2020_count  2020_pct  \
# year          0.000000           0  0.000000           0  0.000000
# ID            0.000000           0  0.000000           0  0.000000
# ticker        0.000000           0  0.000000           0  0.000000
# company_name  0.000000           0  0.000000           0  0.000000
# market_cap    0.151573           5  0.195008           2  0.076628
#
#               2021_count  2021_pct  2022_count  2022_pct  total_count  \
# year                   0       0.0           0       0.0            0
# ID                     0       0.0           0       0.0            0
# ticker                 0       0.0           0       0.0            1
# company_name           0       0.0           0       0.0            0
# market_cap             0       0.0           0       0.0           19
#
#               total_pct
# year           0.000000
# ID             0.000000
# ticker         0.005491
# company_name   0.000000
# market_cap     0.104321

# %%
sorted_df = df_missing.sort_values(by='total_count', ascending=True)

# for index, row in sorted_df.iterrows():
#     print(f"{index:<35} {row['total_pct']:>7.2f}%")

plt.figure(figsize=(10, 10))
bars = plt.barh(sorted_df.index, sorted_df['total_pct'], color='skyblue')
plt.xlabel('Percentage (%)')
plt.ylabel('Index')
plt.title('Horizontal Bar Chart')
plt.xlim(0, 100)  # Set the x-axis limit to 200

# Annotate each bar with its value
for bar in bars:
    plt.text(bar.get_width() + 2,  # x position of text (2 units right of the bar end)
             bar.get_y() + bar.get_height()/2,  # y position of text (center of the bar)
             f'{bar.get_width():.2f}%',  # text
             va='center')  # vertical alignment

plt.tight_layout()
plt.show()

# %% [markdown]
# The fields with the most missing values (above 20%) are shown below:
# - cash_conversion_cycle      53.75%
# - net_repurchase             43.81%
# - repurchase                 37.24%
# - ipo_date                   33.92%
# - short_term_wc              30.06%
# - pe_ratio                   28.51%
# - long_term_wc               25.56%
# - unlevered_fcf              23.64%
# - modified_wc                23.57%
# - total_return_5y            22.85%
#
# There are 10 fields that have more than 20% of the values missing.

# %% [markdown]
# ## 2. Check the missing values for each row

# %% [markdown]
# Here, we group the rows by the number of total missing values.

# %% [markdown]
# Now, I want to do:
# 1. Make a dataframe df that concatenates df16,df17...df22 vertically (note that df16,df17,...df22 have exactly the same columns)
# 2. Count the number of missing values for each row
# 3. And the group the rows by the number of missing values.
# 4. Plot the bar chart such that you have number of missing values on the x axis in the ascending order starting from 0, and the number of the rows that have that many missing values on the y axis (Please write the number of the counts for each bar at the top of each bar)

# %%
df['missing_count'] = df.isnull().sum(axis=1)
grouped = df['missing_count'].value_counts()

# Ensure all possible values are in the index
for i in range(df.shape[1] + 1):  # +1 because range is exclusive at the end
    if i not in grouped:
        grouped[i] = 0

grouped = grouped.sort_index()

# 4. Plot the bar chart
ax = grouped.plot(kind='bar', figsize=(12, 6))
plt.xlabel('Number of Missing Values')
plt.ylabel('Number of Rows')
plt.title('Number of Rows by Missing Values Count')

# Annotate the bars with the count values
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# After done with data imputation, we might need to consider dropping some rows that has too many missing values. The specific threshold should be discussed later.

# %% [markdown]
# # 3. Conclusions

# %% [markdown]
# 1. There are 10 fields with missing values of higher than 20%.
# 2. Most of the companies have missing values of fewer than 20 out of 81 fields.
