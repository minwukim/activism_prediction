# %% [markdown]
# # Data preprocessing: data imputation with statistics

# %% [markdown]
# In the previous notebook, we conducted data imputation with by grouping and substitutions with semantically similar columns.
#
# In this notebook, we impute the rest of the data using statistical approaches (mean, median, etc.)

# %% [markdown]
# # Data & Package import

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../database/2016-2022_semantic_imputation.csv')
# Out:
# /var/folders/kw/6hnl881s2p9701b42gpjt_pr0000gn/T/ipykernel_46219/454442991.py:1: DtypeWarning: Columns (7,8,65,67,74,75,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../database/2016-2022_semantic_imputation.csv')

# %%
df.head()
# Out:
#    year                  ID    ticker                    company_name  \
# 0  2016  1518855D US Equity  1518855D  Yahoo! Inc - Set up for Fundam
# 1  2016  1539941D UN Equity  1539941D              Spectra Energy LLC
# 2  2016  1556442D UA Equity  1556442D                     GigPeak Inc
# 3  2016  1624831D UN Equity  1624831D           TIAA FSB Holdings Inc
# 4  2016  1627503D UN Equity  1627503D          Colony Capital Inc/Old
#
#      market_cap                     bic_level_2                bic_level_3  \
# 0  3.690000e+10                           Media  Internet Media & Services
# 1  2.880000e+10                       Oil & Gas        Oil & Gas Producers
# 2  1.710000e+08  Tech Hardware & Semiconductors             Semiconductors
# 3  2.460000e+09                         Banking                    Banking
# 4  2.310000e+09              Financial Services          Specialty Finance
#
#   unequal_voting ceo_tenure ipo_date  ...  dividend_to_common  \
# 0            0.0        9.0      NaN  ...        0.000000e+00
# 1            0.0       4.25      NaN  ...        1.090000e+09
# 2            0.0    9.66667      NaN  ...        0.000000e+00
# 3            0.0       20.0      NaN  ...        3.004690e+07
# 4            1.0    7.33333      NaN  ...        1.810000e+08
#
#    dividend_to_preferred  dividend_payout_ratio  \
# 0                    0.0               -0.00000
# 1                    NaN              345.47300
# 2                    0.0                0.00000
# 3             10125000.0               24.70332
# 4             48200000.0              176.07490
#
#    total_compensation_to_executives  total_compensation_to_board_members  \
# 0                         8510000.0                            1150000.0
# 1                        23471757.0                          3602528.659
# 2                       126000000.0                                  NaN
# 3                         8194543.0                            1068000.0
# 4                        55521900.0                            1970000.0
#
#    institution_ownership_percertage  asset_to_equity  cash_conversion_cycle  \
# 0                               NaN             1.57                    NaN
# 1                              79.1             3.00                   14.6
# 2                              41.5             1.30                  173.0
# 3                              89.0            15.10                    NaN
# 4                             118.0             1.80                    NaN
#
#    final_shares_outstanding  targeted
# 0               954000000.0         0
# 1               702000000.0         0
# 2                67700000.0         0
# 3               127000000.0         0
# 4               113000000.0         0
#
# [5 rows x 81 columns]

# %% [markdown]
# # A. Binary variables
#
# - 1. unequal_voting
# - 2. classified_board_system
# - 3. poison_pill

# %% [markdown]
# # 1. unequal_voting

# %% [markdown]
# unify the data type first.

# %%
unique_values = df['unequal_voting'].unique()
for value in unique_values:
    print(f"Value: {value}, Type: {type(value)}")
# Out:
# Value: 0.0, Type: <class 'str'>
# Value: 1.0, Type: <class 'str'>
# Value: nan, Type: <class 'float'>
# Value: 0, Type: <class 'str'>
# Value: 1, Type: <class 'str'>
# Value: #N/A Invalid Security, Type: <class 'str'>
# Value: 0.0, Type: <class 'float'>
# Value: 1.0, Type: <class 'float'>

# %%
def transform_value(value):
    if value in ['0', '0.0', 0.0]:
        return 0.0
    elif value in ['1', '1.0', 1.0]:
        return 1.0
    else:
        return np.nan

df['unequal_voting'] = df['unequal_voting'].apply(transform_value)

# %% [markdown]
# ### 1.1. pie chart

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} counts)".format(pct, absolute)

plt.figure(figsize=(6, 6))  #
value_counts = df['unequal_voting'].value_counts(dropna=False)
wedges, texts, autotexts = plt.pie(value_counts, 
                                   autopct=lambda pct: func(pct, value_counts), 
                                   startangle=90, 
                                   pctdistance=0.85, 
                                   labels=value_counts.index)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.setp(autotexts, size=10, weight="bold")
plt.title('Distribution of unequal_voting')
plt.legend(loc="best", bbox_to_anchor=(1, 0.5), labels=['%s, %1.1f%%' % (l, (float(s) / sum(value_counts) * 100)) for l, s in zip(value_counts.index, value_counts)])
plt.show()

# %% [markdown]
# ### 1.2. data imputation

# %% [markdown]
# As the majority of the companies do not have voting rights, we fill the null values with zero as well.

# %%
df['unequal_voting'].fillna(0.0, inplace=True)
# mean_value = df['unequal_voting'].mean()
# df['unequal_voting'].fillna(mean_value, inplace=True)

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} counts)".format(pct, absolute)

plt.figure(figsize=(6, 6))  #
value_counts = df['unequal_voting'].value_counts(dropna=False)
wedges, texts, autotexts = plt.pie(value_counts, 
                                   autopct=lambda pct: func(pct, value_counts), 
                                   startangle=90, 
                                   pctdistance=0.85, 
                                   labels=value_counts.index)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.setp(autotexts, size=10, weight="bold")
plt.title('Distribution of unequal_voting')
plt.legend(loc="best", bbox_to_anchor=(1, 0.5), labels=['%s, %1.1f%%' % (l, (float(s) / sum(value_counts) * 100)) for l, s in zip(value_counts.index, value_counts)])
plt.show()

# %% [markdown]
# # 2. classified_board_system

# %% [markdown]
# ### 2.1 pie chart

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} counts)".format(pct, absolute)

plt.figure(figsize=(6, 6))  
value_counts = df['classified_board_system'].value_counts(dropna=False)
wedges, texts, autotexts = plt.pie(value_counts, 
                                   autopct=lambda pct: func(pct, value_counts), 
                                   startangle=90, 
                                   pctdistance=0.85, 
                                   labels=value_counts.index)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.setp(autotexts, size=10, weight="bold")
plt.title('Distribution of classified_board_system')
plt.legend(loc="best", bbox_to_anchor=(1, 0.5), labels=['%s, %1.1f%%' % (l, (float(s) / sum(value_counts) * 100)) for l, s in zip(value_counts.index, value_counts)])
plt.show()

# %% [markdown]
# ### 2.2. data imputation

# %% [markdown]
# As there is a balanced distribution of the binary variable classified_board_system, impute the missing data with the mean value.

# %%
mean_value = df['classified_board_system'].mean()
df['classified_board_system'].fillna(mean_value, inplace=True)

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} counts)".format(pct, absolute)

plt.figure(figsize=(6, 6))  
value_counts = df['classified_board_system'].value_counts(dropna=False)
wedges, texts, autotexts = plt.pie(value_counts, 
                                   autopct=lambda pct: func(pct, value_counts), 
                                   startangle=90, 
                                   pctdistance=0.85, 
                                   labels=value_counts.index)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.setp(autotexts, size=10, weight="bold")
plt.title('Distribution of classified_board_system')
plt.legend(loc="best", bbox_to_anchor=(1, 0.5), labels=['%s, %1.1f%%' % (l, (float(s) / sum(value_counts) * 100)) for l, s in zip(value_counts.index, value_counts)])
plt.show()

# %% [markdown]
# # 3. poison_pill

# %% [markdown]
# We first unify the data types.

# %%
unique_values = df['poison_pill'].unique()
for value in unique_values:
    print(f"Value: {value}, Type: {type(value)}")
# Out:
# Value: 0.0, Type: <class 'str'>
# Value: 1.0, Type: <class 'str'>
# Value: nan, Type: <class 'float'>
# Value: 0, Type: <class 'str'>
# Value: 1, Type: <class 'str'>
# Value: #N/A Invalid Security, Type: <class 'str'>
# Value: 0.0, Type: <class 'float'>
# Value: 1.0, Type: <class 'float'>

# %%
df['poison_pill'] = df['poison_pill'].apply(transform_value)

# %% [markdown]
# ### 3.1. pie chart

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} counts)".format(pct, absolute)

plt.figure(figsize=(6, 6))  
value_counts = df['poison_pill'].value_counts(dropna=False)
wedges, texts, autotexts = plt.pie(value_counts, 
                                   autopct=lambda pct: func(pct, value_counts), 
                                   startangle=90, 
                                   pctdistance=0.85, 
                                   labels=value_counts.index)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.setp(autotexts, size=10, weight="bold")
plt.title('Distribution of poison_pill')
plt.legend(loc="best", bbox_to_anchor=(1, 0.5), labels=['%s, %1.1f%%' % (l, (float(s) / sum(value_counts) * 100)) for l, s in zip(value_counts.index, value_counts)])
plt.show()

# %% [markdown]
# ### 3.2 data imputation

# %% [markdown]
# As the majority of the companies do not have the poison pill plan, we fill in the missing values as 0 as well.

# %%
df['poison_pill'].fillna(0.0, inplace=True)
# mean_value = df['poison_pill'].mean()
# df['poison_pill'].fillna(mean_value, inplace=True)

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} counts)".format(pct, absolute)

plt.figure(figsize=(6, 6))  
value_counts = df['poison_pill'].value_counts(dropna=False)
wedges, texts, autotexts = plt.pie(value_counts, 
                                   autopct=lambda pct: func(pct, value_counts), 
                                   startangle=90, 
                                   pctdistance=0.85, 
                                   labels=value_counts.index)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.setp(autotexts, size=10, weight="bold")
plt.title('Distribution of poison_pill')
plt.legend(loc="best", bbox_to_anchor=(1, 0.5), labels=['%s, %1.1f%%' % (l, (float(s) / sum(value_counts) * 100)) for l, s in zip(value_counts.index, value_counts)])
plt.show()

# %% [markdown]
# ## Binary values summary:

# %% [markdown]
# For three binary values, we executed data imputation as such:
# - unequal_voting: As 87.2% was 0, we imputed the N/A with 0 too.
# - classified_board_system: As there was a even distribution of 0 and 1, we imputed the N/A with the mean value (~0.4)
# - poison_pill: As 89.2% was 0, we imputed the N/A with 0 too.

# %% [markdown]
# # B. Non-ratio variables

# %% [markdown]
# For non-ratio variables, the magnitudes of numbers tend to go along with the market cap of companies.
# Therefore, we make these columns for each of them:
#
# 1. percentile rank
# 2. market_cap - 10 bins - percentile rank
# 3. market_cap - 10 bins - normalized
# 4. market_cap - divide by market_cap
# 5. market_cap - divide by log(market_cap)
# 6. raw values
#
# In order to do so, we first need to deal with the column **market_cap**: We fill the value of market_cap with the **median** value of each year.

# %%
total_rows = len(df)
market_cap_missing = df['market_cap'].isna().sum()
market_cap_percentage = (market_cap_missing / total_rows) * 100
print(f"Rows where 'market_cap' is missing: {market_cap_missing} ({market_cap_percentage:.2f}%)")
# Out:
# Rows where 'market_cap' is missing: 19 (0.10%)

# %%
# Filter rows where 'market_cap' is missing
missing_market_cap_rows = df[df['market_cap'].isna()]
# Count missing values for each of these rows
missing_values_counts = missing_market_cap_rows.isna().sum(axis=1)

for index, count in missing_values_counts.items():
    year_value = missing_market_cap_rows.loc[index, 'year']
    ID_value = missing_market_cap_rows.loc[index, 'ID']
    print(f"Row index {index} with Year: {year_value} and ID: {ID_value} has {count} missing values. (index: {index})")
# Out:
# Row index 28 with Year: 2016 and ID: 1872828D UW Equity has 63 missing values. (index: 28)
# Row index 80 with Year: 2016 and ID: 9876588D UW Equity has 63 missing values. (index: 80)
# Row index 94 with Year: 2016 and ID: 9995522D UW Equity has 63 missing values. (index: 94)
# Row index 2559 with Year: 2016 and ID: VR UN Equity has 71 missing values. (index: 2559)
# Row index 2743 with Year: 2017 and ID: 1872828D UW Equity has 63 missing values. (index: 2743)
# Row index 2778 with Year: 2017 and ID: 9876588D UW Equity has 64 missing values. (index: 2778)
# Row index 2791 with Year: 2017 and ID: 9995522D UW Equity has 62 missing values. (index: 2791)
# Row index 5204 with Year: 2017 and ID: VR has 68 missing values. (index: 5204)
# Row index 5365 with Year: 2018 and ID: 1872828D UW Equity has 64 missing values. (index: 5365)
# Row index 5394 with Year: 2018 and ID: 9876588D UW Equity has 64 missing values. (index: 5394)
# Row index 5410 with Year: 2018 and ID: 9992011D UN Equity has 17 missing values. (index: 5410)
# Row index 5412 with Year: 2018 and ID: 9995522D UW Equity has 63 missing values. (index: 5412)
# Row index 8002 with Year: 2019 and ID: 1872828D UW Equity has 64 missing values. (index: 8002)
# Row index 8011 with Year: 2019 and ID: 1998018D UN Equity has 23 missing values. (index: 8011)
# Row index 8024 with Year: 2019 and ID: 9876588D UW Equity has 64 missing values. (index: 8024)
# Row index 8040 with Year: 2019 and ID: 9992011D UN Equity has 12 missing values. (index: 8040)
# Row index 8043 with Year: 2019 and ID: 9995522D UW Equity has 63 missing values. (index: 8043)
# Row index 10576 with Year: 2020 and ID: 2297264D UW Equity has 17 missing values. (index: 10576)
# Row index 11547 with Year: 2020 and ID: FTCO US Equity has 54 missing values. (index: 11547)

# %%
 # Calculate the median value of 'market_cap' for each year
median_values_per_year = df.groupby('year')['market_cap'].transform('median')

# Impute missing values in 'market_cap' with the median value of the respective year
df['market_cap'].fillna(median_values_per_year, inplace=True)

# %% [markdown]
# Then, we do the make new columns as explained above

# %% [markdown]
# ## All the non-ratio variables are shown below:
# - capex
# - net_capex
# - short_term_wc
# - long_term_wc
# - ebitda
# - ebit
# - net_income
# - net_debt
# - ev
# - repurchase
# - net_repurchase
# - total_compensation_to_executives
# - total_compensation_to_board_members
#
#
# ## As mentioned, we do these 6 operations as shown below:
# 1. **_percentile**
#     - stores the percentile rank grouped by each year (0-100).
#     - missing values are filled with 50.
# 2. **_10bins_percentile**
#     - stores the percentile rank grouped by each year and 10 bins of market cap.
#     - missing values are filled with 50.
# 3. **_10bins_normalized**
#     - stores the percentile rank grouped by each year and 10 bins of market cap in each year.
#     - missing values are filled with 0.
# 4. **_div_market_cap**
#     - stores the value divided by market_cap
#     - missing values are filled with median values.
# 5. **_div_log_market_cap**
#     - stores the value divided by logarithm of market_cap.
#     - missing values are filled with median values.
# 6. **original**
#     - missing values are filled with median values

# %%
columns_to_process = [
    "capex",
    "net_capex",
    "short_term_wc",
    "long_term_wc",
    "ebitda",
    "ebit",
    "net_income",
    "net_debt",
    "ev",
    "repurchase",
    "board_size",
    "net_repurchase",
    "total_compensation_to_executives",
    "total_compensation_to_board_members"
]

print(f"{'Column':<40} {'Missing rows':<15} {'Percentage':<10}")
print('-' * 70) 
for col in columns_to_process:
    
    df[col] = pd.to_numeric(df[col], errors='coerce')
    
    missing_rows = df[col].isna().sum()
    total_rows = len(df)
    missing_percentage = (missing_rows / total_rows) * 100
    print(f"{col:<40} {missing_rows:<15} {missing_percentage:.2f}%")
    
    # 1. _percentile
    percentile_col = col + '_percentile'
    df[percentile_col] = df.groupby('year')[col].transform(lambda x: x.rank(pct=True) * 100)
    df[percentile_col].fillna(50, inplace=True)
    
    # 2. _10bins_percentile
    df['market_cap_bins'] = df.groupby('year')['market_cap'].transform(lambda x: pd.cut(x, bins=10))
    percentile_10bins_col = col + '_10bins_percentile'
    df[percentile_10bins_col] = df.groupby(['year', 'market_cap_bins'])[col].transform(lambda x: x.rank(pct=True) * 100)
    df[percentile_10bins_col].fillna(50, inplace=True)
    df.drop('market_cap_bins', axis=1, inplace=True)

    # 3. _10bins_normalized
    df['market_cap_bins'] = df.groupby('year')['market_cap'].transform(lambda x: pd.qcut(x, 10, labels=False, duplicates='drop'))
    normalized_col = col + '_10bins_normalized'
    df[normalized_col] = df.groupby(['year', 'market_cap_bins'])[col].transform(lambda x: (x - x.mean()) / x.std())
    df[normalized_col].fillna(0, inplace=True)
    df.drop('market_cap_bins', axis=1, inplace=True)

    
    # 4. _div_market_cap
    div_market_cap_col = col + '_div_market_cap'
    df[div_market_cap_col] = df[col] / df['market_cap']
    
    # 5. _div_log_market_cap
    df['log_market_cap'] = np.log(df['market_cap'])
    div_log_market_cap_col = col + '_div_log_market_cap'
    df[div_log_market_cap_col] = df[col] / df['log_market_cap']
    
    for new_col in [div_market_cap_col, div_log_market_cap_col]:
        median_values = df.groupby('year')[new_col].transform('median')
        df[new_col].fillna(median_values, inplace=True)
    df.drop('log_market_cap', axis=1, inplace=True)
    
    # 6. raw values
    df[col].fillna(df.groupby('year')[col].transform('median'), inplace=True)
# Out:
# Column                                   Missing rows    Percentage
# ----------------------------------------------------------------------
# capex                                    772             4.24%
# net_capex                                772             4.24%
# short_term_wc                            5475            30.06%
# long_term_wc                             4655            25.56%
# ebitda                                   2099            11.52%
# ebit                                     2099            11.52%
# net_income                               182             1.00%
# net_debt                                 125             0.69%
# ev                                       2087            11.46%
# repurchase                               6782            37.24%
# board_size                               470             2.58%
# net_repurchase                           6782            37.24%
# total_compensation_to_executives         790             4.34%
# total_compensation_to_board_members      911             5.00%

# %% [markdown]
# # C. ratio variables (non-technical)

# %% [markdown]
# For the ratio variables, the values are often comparable with the industry peers. Therefore, we create the new columns as shown below:
# 1. **_industry_peers_percentile**
#     - Group the companies by industry and year, and compute the percentile
#     - Fill the missing values with 50.
# 2. **_industry_peers_normalized**
#     - Group the companies by industry and year, and compute the percentile
#     - Fill the missing values with 0.
# 3. **original**
#     - Fill the missing values with the median value

# %% [markdown]
# ### The ratio variables are shown below:
# - ebitda_margin
# - operating_margin
# - sales_to_total_assets
# - normalized_roe
# - operating_roe
# - operating_roic
# - eps_adjusted_diluted
# - ev_to_sales
# - tobin_q_ratio
# - pb_ratio
# - fcf_to_equity
# - sales_growth_rate
# - dividend_per_share
# - dividend_payout_ratio
# - asset_to_equity
# - cash_conversion_cycle
# - ev_ebitda
# - ev_ebit

# %% [markdown]
# #### First, we make ev_ebitda and ev_ebit as shown below:

# %%
df['ev_ebitda'] = np.where((df['ev'] != 0) & (df['ebitda'] != 0), df['ev'] / df['ebitda'], np.nan)
df['ev_ebit'] = np.where((df['ev'] != 0) & (df['ebit'] != 0), df['ev'] / df['ebit'], np.nan)

# %% [markdown]
# #### Then, we execute the operation as shown above.

# %% [markdown]
# We first group the dataframe df by 'year', and print all the unique values of 'bic_level_2' and "bic_level_3" with the number of counts for each year

# %%
grouped_by_year = df.groupby('year')

for year, group in grouped_by_year:
    print(f"Year: {year}")
    
    # Unique values and counts for 'bic_level_2'
    bic_level_2_counts = group['bic_level_2'].value_counts()
    print("\nUnique values for 'bic_level_2':")
    print(bic_level_2_counts)
    
    # Unique values and counts for 'bic_level_3'
    bic_level_3_counts = group['bic_level_3'].value_counts()
    print("\nUnique values for 'bic_level_3':")
    print(bic_level_3_counts)
    
    print("\n" + "-"*50 + "\n")
# Out:
# Year: 2016
#
# Unique values for 'bic_level_2':
# Health Care                        421
# Banking                            272
# Software & Tech Services           208
# Real Estate                        179
# Industrial Services                178
# Industrial Products                172
# Tech Hardware & Semiconductors     142
# Financial Services                 141
# Materials                          135
# Oil & Gas                          123
# Consumer Discretionary Products    122
# Retail & Whsle - Discretionary     109
# Consumer Discretionary Services    101
# Insurance                           91
# Media                               88
# Consumer Staple Products            82
# Utilities                           77
# Telecommunications                  39
# Retail & Wholesale - Staples        30
# Renewable Energy                    15
# Name: bic_level_2, dtype: int64
#
# Unique values for 'bic_level_3':
# Banking                            272
# Biotech & Pharma                   231
# REIT                               165
# Software                           122
# Medical Equipment & Devices        116
# Insurance                           91
# Retail - Discretionary              90
# Technology Services                 86
# Leisure Facilities & Services       81
# Oil & Gas Producers                 78
# Technology Hardware                 75
# Health Care Facilities & Svcs       74
# Specialty Finance                   73
# Commercial Support Services         68
# Semiconductors                      67
# Transportation & Logistics          63
# Chemicals                           62
# Machinery                           54
# Electric Utilities                  50
# Food                                47
# Oil & Gas Services & Equip          45
# Electrical Equipment                44
# Asset Management                    41
# Telecommunications                  39
# Internet Media & Services           33
# Aerospace & Defense                 33
# Home Construction                   32
# Automotive                          28
# Institutional Financial Svcs        27
# Apparel & Textile Products          26
# Gas & Water Utilities               25
# Engineering & Construction          24
# Industrial Support Services         23
# Publishing & Broadcasting           22
# Leisure Products                    21
# Retail - Consumer Staples           21
# Consumer Services                   20
# Containers & Packaging              20
# Industrial Intermediate Prod        20
# Metals & Mining                     16
# Entertainment Content               16
# Household Products                  16
# Construction Materials              16
# Renewable Energy                    15
# Home & Office Products              15
# Steel                               14
# Transportation Equipment            13
# Beverages                           12
# E-Commerce Discretionary            10
# Advertising & Marketing             10
# Wholesale - Consumer Staples         9
# Wholesale - Discretionary            9
# Diversified Industrials              8
# Real Estate Owners & Developers      8
# Forestry, Paper & Wood Products      7
# Cable & Satellite                    7
# Tobacco & Cannabis                   7
# Real Estate Services                 6
# Elec & Gas Marketing & Trading       2
# Name: bic_level_3, dtype: int64
#
# --------------------------------------------------
#
# Year: 2017
#
# Unique values for 'bic_level_2':
# Health Care                        387
# Banking                            287
# Software & Tech Services           197
# Industrial Services                177
# Real Estate                        172
# Industrial Products                169
# Materials                          139
# Tech Hardware & Semiconductors     137
# Financial Services                 134
# Oil & Gas                          127
# Consumer Discretionary Products    115
# Retail & Whsle - Discretionary     104
# Consumer Discretionary Services     93
# Insurance                           91
# Media                               85
# Utilities                           77
# Consumer Staple Products            68
# Telecommunications                  34
# Retail & Wholesale - Staples        27
# Renewable Energy                    14
# Name: bic_level_2, dtype: int64
#
# Unique values for 'bic_level_3':
# Banking                            287
# Biotech & Pharma                   220
# REIT                               156
# Software                           119
# Medical Equipment & Devices        105
# Insurance                           91
# Retail - Discretionary              87
# Oil & Gas Producers                 82
# Technology Services                 78
# Leisure Facilities & Services       73
# Technology Hardware                 73
# Specialty Finance                   72
# Commercial Support Services         66
# Semiconductors                      64
# Transportation & Logistics          64
# Chemicals                           63
# Health Care Facilities & Svcs       62
# Machinery                           54
# Electric Utilities                  49
# Electrical Equipment                45
# Oil & Gas Services & Equip          45
# Food                                38
# Asset Management                    37
# Telecommunications                  34
# Aerospace & Defense                 31
# Home Construction                   30
# Internet Media & Services           29
# Gas & Water Utilities               26
# Institutional Financial Svcs        25
# Apparel & Textile Products          24
# Engineering & Construction          24
# Automotive                          23
# Industrial Support Services         23
# Leisure Products                    22
# Publishing & Broadcasting           22
# Metals & Mining                     21
# Consumer Services                   20
# Industrial Intermediate Prod        20
# Containers & Packaging              19
# Retail - Consumer Staples           18
# Entertainment Content               16
# Steel                               16
# Home & Office Products              16
# Renewable Energy                    14
# Construction Materials              14
# Household Products                  13
# Transportation Equipment            13
# Beverages                           12
# Wholesale - Discretionary           10
# Advertising & Marketing             10
# Real Estate Owners & Developers     10
# Wholesale - Consumer Staples         9
# Cable & Satellite                    8
# E-Commerce Discretionary             7
# Forestry, Paper & Wood Products      6
# Real Estate Services                 6
# Diversified Industrials              6
# Tobacco & Cannabis                   5
# Elec & Gas Marketing & Trading       2
# Name: bic_level_3, dtype: int64
#
# --------------------------------------------------
#
# Year: 2018
#
# Unique values for 'bic_level_2':
# Health Care                        451
# Banking                            300
# Software & Tech Services           195
# Real Estate                        177
# Industrial Services                175
# Industrial Products                164
# Tech Hardware & Semiconductors     134
# Materials                          133
# Financial Services                 130
# Oil & Gas                          126
# Consumer Discretionary Products    107
# Retail & Whsle - Discretionary      95
# Insurance                           88
# Consumer Discretionary Services     88
# Media                               78
# Utilities                           68
# Consumer Staple Products            62
# Telecommunications                  29
# Retail & Wholesale - Staples        24
# Renewable Energy                    15
# Name: bic_level_2, dtype: int64
#
# Unique values for 'bic_level_3':
# Banking                            300
# Biotech & Pharma                   280
# REIT                               158
# Software                           119
# Medical Equipment & Devices        109
# Insurance                           88
# Retail - Discretionary              79
# Oil & Gas Producers                 78
# Technology Services                 76
# Technology Hardware                 75
# Leisure Facilities & Services       70
# Specialty Finance                   68
# Commercial Support Services         65
# Transportation & Logistics          63
# Health Care Facilities & Svcs       62
# Semiconductors                      59
# Chemicals                           58
# Machinery                           57
# Oil & Gas Services & Equip          48
# Electric Utilities                  45
# Electrical Equipment                43
# Asset Management                    37
# Food                                33
# Internet Media & Services           31
# Telecommunications                  29
# Aerospace & Defense                 28
# Home Construction                   28
# Institutional Financial Svcs        25
# Engineering & Construction          24
# Industrial Support Services         23
# Gas & Water Utilities               22
# Apparel & Textile Products          22
# Metals & Mining                     21
# Leisure Products                    21
# Automotive                          21
# Publishing & Broadcasting           19
# Steel                               18
# Consumer Services                   18
# Containers & Packaging              18
# Industrial Intermediate Prod        18
# Retail - Consumer Staples           17
# Home & Office Products              15
# Renewable Energy                    15
# Entertainment Content               13
# Beverages                           13
# Construction Materials              12
# Transportation Equipment            12
# Real Estate Owners & Developers     11
# Household Products                  10
# Wholesale - Discretionary            9
# Cable & Satellite                    8
# Real Estate Services                 8
# E-Commerce Discretionary             7
# Wholesale - Consumer Staples         7
# Advertising & Marketing              7
# Forestry, Paper & Wood Products      6
# Diversified Industrials              6
# Tobacco & Cannabis                   6
# Elec & Gas Marketing & Trading       1
# Name: bic_level_3, dtype: int64
#
# --------------------------------------------------
#
# Year: 2019
#
# Unique values for 'bic_level_2':
# Health Care                        471
# Banking                            292
# Software & Tech Services           184
# Real Estate                        175
# Industrial Services                162
# Industrial Products                160
# Financial Services                 135
# Tech Hardware & Semiconductors     125
# Materials                          124
# Oil & Gas                          108
# Consumer Discretionary Products    104
# Retail & Whsle - Discretionary      91
# Insurance                           87
# Media                               78
# Consumer Discretionary Services     78
# Consumer Staple Products            66
# Utilities                           64
# Telecommunications                  23
# Retail & Wholesale - Staples        23
# Renewable Energy                    14
# Name: bic_level_2, dtype: int64
#
# Unique values for 'bic_level_3':
# Biotech & Pharma                   297
# Banking                            292
# REIT                               154
# Software                           121
# Medical Equipment & Devices        113
# Insurance                           87
# Retail - Discretionary              72
# Specialty Finance                   71
# Technology Hardware                 70
# Oil & Gas Producers                 68
# Technology Services                 63
# Health Care Facilities & Svcs       61
# Transportation & Logistics          61
# Leisure Facilities & Services       61
# Commercial Support Services         59
# Chemicals                           57
# Semiconductors                      55
# Machinery                           54
# Electrical Equipment                45
# Electric Utilities                  42
# Asset Management                    40
# Oil & Gas Services & Equip          40
# Food                                36
# Internet Media & Services           30
# Aerospace & Defense                 28
# Apparel & Textile Products          26
# Home Construction                   25
# Institutional Financial Svcs        24
# Telecommunications                  23
# Engineering & Construction          21
# Industrial Support Services         21
# Metals & Mining                     21
# Gas & Water Utilities               20
# Leisure Products                    20
# Automotive                          18
# Publishing & Broadcasting           17
# Industrial Intermediate Prod        17
# Consumer Services                   17
# Steel                               16
# Retail - Consumer Staples           16
# Containers & Packaging              16
# Home & Office Products              15
# Renewable Energy                    14
# Entertainment Content               14
# Beverages                           13
# Real Estate Owners & Developers     12
# Transportation Equipment            11
# E-Commerce Discretionary            10
# Household Products                  10
# Advertising & Marketing              9
# Wholesale - Discretionary            9
# Real Estate Services                 9
# Construction Materials               9
# Cable & Satellite                    8
# Wholesale - Consumer Staples         7
# Tobacco & Cannabis                   7
# Forestry, Paper & Wood Products      5
# Diversified Industrials              5
# Elec & Gas Marketing & Trading       2
# Name: bic_level_3, dtype: int64
#
# --------------------------------------------------
#
# Year: 2020
#
# Unique values for 'bic_level_2':
# Health Care                        550
# Banking                            302
# Software & Tech Services           212
# Real Estate                        174
# Industrial Products                160
# Industrial Services                157
# Financial Services                 134
# Materials                          123
# Tech Hardware & Semiconductors     122
# Consumer Discretionary Products    100
# Retail & Whsle - Discretionary      87
# Insurance                           85
# Consumer Discretionary Services     75
# Media                               73
# Oil & Gas                           69
# Consumer Staple Products            64
# Utilities                           61
# Retail & Wholesale - Staples        25
# Telecommunications                  19
# Renewable Energy                    18
# Name: bic_level_2, dtype: int64
#
# Unique values for 'bic_level_3':
# Biotech & Pharma                   354
# Banking                            302
# REIT                               152
# Software                           141
# Medical Equipment & Devices        131
# Insurance                           85
# Technology Services                 71
# Specialty Finance                   71
# Retail - Discretionary              69
# Technology Hardware                 66
# Health Care Facilities & Svcs       65
# Commercial Support Services         57
# Leisure Facilities & Services       56
# Transportation & Logistics          56
# Semiconductors                      56
# Chemicals                           54
# Machinery                           53
# Electrical Equipment                51
# Oil & Gas Producers                 45
# Electric Utilities                  38
# Asset Management                    38
# Food                                36
# Internet Media & Services           31
# Institutional Financial Svcs        25
# Name: bic_level_3, dtype: int64
#
# --------------------------------------------------
#
# Year: 2022
#
# Unique values for 'bic_level_2':
# Health Care                        425
# Software & Tech Services           245
# Banking                            226
# Industrial Products                167
# Real Estate                        152
# Industrial Services                149
# Financial Services                 134
# Materials                          123
# Tech Hardware & Semiconductors     118
# Consumer Discretionary Products    109
# Retail & Whsle - Discretionary      91
# Consumer Discretionary Services     78
# Media                               77
# Oil & Gas                           74
# Insurance                           73
# Consumer Staple Products            71
# Utilities                           56
# Renewable Energy                    26
# Retail & Wholesale - Staples        24
# Telecommunications                  16
# Name: bic_level_2, dtype: int64
#
# Unique values for 'bic_level_3':
# Biotech & Pharma                   250
# Banking                            226
# Software                           164
# REIT                               130
# Medical Equipment & Devices        106
# Technology Services                 81
# Insurance                           73
# Specialty Finance                   71
# Health Care Facilities & Svcs       69
# Retail - Discretionary              65
# Technology Hardware                 65
# Leisure Facilities & Services       57
# Commercial Support Services         56
# Semiconductors                      53
# Electrical Equipment                52
# Oil & Gas Producers                 51
# Chemicals                           50
# Machinery                           49
# Transportation & Logistics          49
# Food                                40
# Asset Management                    38
# Electric Utilities                  38
# Internet Media & Services           31
# Metals & Mining                     30
# Aerospace & Defense                 29
# Automotive                          28
# Home Construction                   27
# Renewable Energy                    26
# Institutional Financial Svcs        25
# Apparel & Textile Products          24
# Oil & Gas Services & Equip          23
# Industrial Support Services         22
# Engineering & Construction          22
# Consumer Services                   21
# Containers & Packaging              18
# E-Commerce Discretionary            17
# Industrial Intermediate Prod        17
# Retail - Consumer Staples           17
# Leisure Products                    17
# Gas & Water Utilities               17
# Telecommunications                  16
# Transportation Equipment            15
# Steel                               14
# Entertainment Content               14
# Publishing & Broadcasting           13
# Beverages                           13
# Household Products                  13
# Home & Office Products              13
# Advertising & Marketing             12
# Real Estate Owners & Developers     11
# Real Estate Services                11
# Wholesale - Discretionary            9
# Construction Materials               8
# Cable & Satellite                    7
# Wholesale - Consumer Staples         7
# Diversified Industrials              5
# Tobacco & Cannabis                   5
# Forestry, Paper & Wood Products      3
# Elec & Gas Marketing & Trading       1
# Name: bic_level_3, dtype: int64
#
# --------------------------------------------------

# %% [markdown]
# #### Bloomberg's model implemented such a policy:
# *When factors are created from ranking against industry peers, BICS (Bloomberg Industry Classification System) Level 3 industries are used. If a company is the only member of its industry in the universe (Russell 3000), then BICS Level 2 industry groups are used.*
#
# However, our model sets the bar a bit higher so that it will use BICs Level 2 when there are fewer than 10 companies in the same group when grouped by BICS Level 3.

# %%
columns_to_process = [
    "ebitda_margin",
    "operating_margin",
    "sales_to_total_assets",
    "normalized_roe",
    "operating_roe",
    "operating_roic",
    "eps_adjusted_diluted",
    "ev_to_sales",
    "tobin_q_ratio",
    "pb_ratio",
    "fcf_to_equity",
    "sales_growth_rate",
    "dividend_per_share",
    "dividend_payout_ratio",
    "asset_to_equity",
    "cash_conversion_cycle",
    "ev_ebitda",
    "ev_ebit"
]

def compute_percentile(group):
    if len(group) < 10:
        return pd.Series([None] * len(group), index=group.index, dtype=float)
    return group.rank(pct=True) * 100

def normalize(group):
    if len(group) < 10:
        return pd.Series([None] * len(group), index=group.index, dtype=float)
    return (group - group.mean()) / group.std()

for col in columns_to_process:
    
    # 1. _industry_peers_percentile
    percentile_col = col + '_industry_peers_percentile'
    df[percentile_col] = df.groupby(['year', 'bic_level_3'])[col].transform(compute_percentile)
    mask = df[percentile_col].isna()
    df.loc[mask, percentile_col] = df[mask].groupby(['year', 'bic_level_2'])[col].transform(compute_percentile)
    df[percentile_col].fillna(50, inplace=True)
    df[percentile_col] = df[percentile_col].astype(float)

    # 2. _industry_peers_normalized
    normalized_col = col + '_industry_peers_normalized'
    df[normalized_col] = df.groupby(['year', 'bic_level_3'])[col].transform(normalize)
    mask = df[normalized_col].isna()
    df.loc[mask, normalized_col] = df[mask].groupby(['year', 'bic_level_2'])[col].transform(normalize)
    df[normalized_col].fillna(0, inplace=True)
    df[normalized_col] = df[normalized_col].astype(float)
    
    # 3. original
    df[col].fillna(df.groupby('year')[col].transform('median'), inplace=True)

# %% [markdown]
# # C. technical variables

# %% [markdown]
# For all the technical variables, we simply fill the missing values with median for each year.
#
# #### The technical variables are shown below:
# - free_float_percentage
# - rsi_14d
# - rsi_30d
# - volatility_30d
# - volatility_90d
# - volatility_180d
# - volume_30d_average_to_outstanding
# - insider_shares_percentage
# - institution_ownership_percentage

# %%
technical_variables = [
    "free_float_percentage",
    "rsi_14d",
    "rsi_30d",
    "volatility_30d",
    "volatility_90d",
    "volatility_180d",
    "volume_30d_average_to_outstanding",
    "insider_shares_percentage",
    "institution_ownership_percentage"
]

for col in technical_variables:
    
    df[col] = pd.to_numeric(df[col], errors='coerce')
    df[col].fillna(df.groupby('year')[col].transform('median'), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1790 try:
# -> 1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    1794         how,
#    1795         axis=data.ndim - 1,
#    1796         min_count=min_count,
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# -> 1039 return cy_op.cython_operation(
#    1040     values=values,
#    1041     axis=axis,
#    1042     min_count=min_count,
#    1043     comp_ids=ids,
#    1044     ngroups=ngroups,
#    1045     **kwargs,
#    1046 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:708, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     700     return self._ea_wrap_cython_operation(
#     701         values,
#     702         min_count=min_count,
#    (...)
#     705         **kwargs,
#     706     )
# --> 708 return self._cython_op_ndim_compat(
#     709     values,
#     710     min_count=min_count,
#     711     ngroups=ngroups,
#     712     comp_ids=comp_ids,
#     713     mask=None,
#     714     **kwargs,
#     715 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:512, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     511     result_mask = result_mask[None, :]
# --> 512 res = self._call_cython_op(
#     513     values2d,
#     514     min_count=min_count,
#     515     ngroups=ngroups,
#     516     comp_ids=comp_ids,
#     517     mask=mask,
#     518     result_mask=result_mask,
#     519     **kwargs,
#     520 )
#     521 if res.shape[0] == 1:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:571, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     570 out_shape = self._get_output_shape(ngroups, values)
# --> 571 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     572 values = self._get_cython_vals(values)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:186, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     184 if how in ["median", "cumprod"]:
#     185     # no fused types -> no __signatures__
# --> 186     raise NotImplementedError(
#     187         f"function is not implemented for this dtype: "
#     188         f"[how->{how},dtype->{dtype_str}]"
#     189     )
#     190 elif "object" not in f.__signatures__:
#     191     # raise NotImplementedError here rather than TypeError later
#
# NotImplementedError: function is not implemented for this dtype: [how->median,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:760, in nanmedian(values, axis, skipna, mask)
#     759 try:
# --> 760     values = values.astype("f8")
#     761 except ValueError as err:
#     762     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: '#N/A Invalid Security'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 14
#       1 technical_variables = [
#       2     "free_float_percentage",
#       3     "rsi_14d",
#    (...)
#      10     "institution_ownership_percertage"
#      11 ]
#      13 for col in technical_variables:
# ---> 14     df[col].fillna(df.groupby('year')[col].transform('median'), inplace=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:446, in SeriesGroupBy.transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     443 @Substitution(klass="Series")
#     444 @Appender(_transform_template)
#     445 def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 446     return self._transform(
#     447         func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     448     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1872, in GroupBy._transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    1868 with com.temp_setattr(self, "observed", True):
#    1869     with com.temp_setattr(self, "as_index", True):
#    1870         # GH#49834 - result needs groups in the index for
#    1871         # _wrap_transform_fast_result
# -> 1872         result = getattr(self, func)(*args, **kwargs)
#    1874 return self._wrap_transform_fast_result(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2212, in GroupBy.median(self, numeric_only)
#    2194 """
#    2195 Compute median of groups, excluding missing values.
#    2196
#    (...)
#    2208     Median of values within each group.
#    2209 """
#    2210 numeric_only_bool = self._resolve_numeric_only("median", numeric_only, axis=0)
# -> 2212 result = self._cython_agg_general(
#    2213     "median",
#    2214     alt=lambda x: Series(x).median(numeric_only=numeric_only_bool),
#    2215     numeric_only=numeric_only,
#    2216 )
#    2217 return result.__finalize__(self.obj, method="groupby")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1810, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, ignore_failures, **kwargs)
#    1806     return result
#    1808 # TypeError -> we may have an exception in trying to aggregate
#    1809 #  continue and exclude the block
# -> 1810 new_mgr = data.grouped_reduce(array_func, ignore_failures=ignore_failures)
#    1812 if not is_ser and len(new_mgr) < orig_len:
#    1813     warn_dropping_nuisance_columns_deprecated(type(self), how, numeric_only)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1804, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    (...)
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
# -> 1804     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1806 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1745, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1740     ser = df.iloc[:, 0]
#    1742 # We do not get here with UDFs, so we know that our dtype
#    1743 #  should always be preserved by the implemented aggregations
#    1744 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1745 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1747 if isinstance(values, Categorical):
#    1748     # Because we only get here with known dtype-preserving
#    1749     #  reductions, we cast back to Categorical.
#    1750     # TODO: if we ever get "rank" working, exclude it here.
#    1751     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1081, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#    1078     preserve_dtype = True
#    1080 else:
# -> 1081     result = self._aggregate_series_pure_python(obj, func)
#    1083 npvalues = lib.maybe_convert_objects(result, try_float=False)
#    1084 if preserve_dtype:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1104, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1101 splitter = get_splitter(obj, ids, ngroups, axis=0)
#    1103 for i, group in enumerate(splitter):
# -> 1104     res = func(group)
#    1105     res = libreduction.extract_result(res)
#    1107     if not initialized:
#    1108         # We only do this validation on the first iteration
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2214, in GroupBy.median.<locals>.<lambda>(x)
#    2194 """
#    2195 Compute median of groups, excluding missing values.
#    2196
#    (...)
#    2208     Median of values within each group.
#    2209 """
#    2210 numeric_only_bool = self._resolve_numeric_only("median", numeric_only, axis=0)
#    2212 result = self._cython_agg_general(
#    2213     "median",
# -> 2214     alt=lambda x: Series(x).median(numeric_only=numeric_only_bool),
#    2215     numeric_only=numeric_only,
#    2216 )
#    2217 return result.__finalize__(self.obj, method="groupby")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11917, in NDFrame._add_numeric_operations.<locals>.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11899 @doc(
#   11900     _num_doc,
#   11901     desc="Return the median of the values over the requested axis.",
#    (...)
#   11915     **kwargs,
#   11916 ):
# > 11917     return NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11413, in NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11405 def median(
#   11406     self,
#   11407     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11411     **kwargs,
#   11412 ) -> Series | float:
# > 11413     return self._stat_function(
#   11414         "median", nanops.nanmedian, axis, skipna, level, numeric_only, **kwargs
#   11415     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:763, in nanmedian(values, axis, skipna, mask)
#     760     values = values.astype("f8")
#     761 except ValueError as err:
#     762     # e.g. "could not convert string to float: 'a'"
# --> 763     raise TypeError(str(err)) from err
#     764 if mask is not None:
#     765     values[mask] = np.nan
#
# TypeError: could not convert string to float: '#N/A Invalid Security'

# %%
for col in technical_variables:
    unique_types = set(df[col].map(type).unique())
    print(f"{col}: {unique_types}")
# Out:
# free_float_percentage: {<class 'float'>}
# rsi_14d: {<class 'float'>}
# rsi_30d: {<class 'float'>}
# volatility_30d: {<class 'float'>}
# volatility_90d: {<class 'float'>}
# volatility_180d: {<class 'float'>}
# volume_30d_average_to_outstanding: {<class 'float'>}
# insider_shares_percentage: {<class 'float'>, <class 'str'>}
# institution_ownership_percertage: {<class 'float'>, <class 'str'>}

# %%
# For institution_ownership_percentage
mask = df['institution_ownership_percentage'].apply(lambda x: isinstance(x, str))
str_values = df.loc[mask, 'institution_ownership_percentage']
for idx, value in str_values.items():
    print(f"Index: {idx}, Value: {value}")

print("\n")

# For insider_shares_percentage
mask = df['insider_shares_percentage'].apply(lambda x: isinstance(x, str))
str_values = df.loc[mask, 'insider_shares_percentage']
for idx, value in str_values.items():
    print(f"Index: {idx}, Value: {value}")
# Out:
# Index: 1, Value: 79.1
# Index: 2, Value: 41.5
# Index: 3, Value: 89.0
# Index: 4, Value: 118.0
# Index: 5, Value: 100.0
# Index: 6, Value: 84.5
# Index: 7, Value: 128.0
# Index: 8, Value: 83.9
# Index: 9, Value: 58.8
# Index: 10, Value: 38.3
# Index: 11, Value: 98.4
# Index: 12, Value: 94.1
# Index: 13, Value: 99.7
# Index: 14, Value: 125.0
# Index: 15, Value: 101.0
# Index: 16, Value: 90.2
# Index: 17, Value: 120.0
# Index: 18, Value: 98.0
# Index: 19, Value: 92.8
# Index: 20, Value: 97.2
# Index: 21, Value: 99.3
# Index: 22, Value: 99.5
# Index: 23, Value: 82.5
# Index: 24, Value: 94.1
# Index: 25, Value: 76.6
# Index: 26, Value: 97.3
# Index: 27, Value: 83.7
# Index: 29, Value: 98.8
# Index: 30, Value: 149.0
# Index: 31, Value: 114.0
# Index: 32, Value: 98.2
# Index: 33, Value: 622.0
# Index: 34, Value: 120.0
# Index: 35, Value: 85.5
# Index: 36, Value: 106.0
# Index: 37, Value: 107.0
# Index: 38, Value: 76.0
# Index: 39, Value: 84.3
# Index: 40, Value: 90.3
# Index: 41, Value: 128.0
# Index: 42, Value: 97.0
# Index: 43, Value: 99.8
# Index: 45, Value: 93.7
# Index: 46, Value: 116.0
# Index: 47, Value: 108.0
# Index: 48, Value: 98.1
# Index: 49, Value: 66.3
# Index: 50, Value: 110.0
# Index: 51, Value: 85.4
# Index: 52, Value: 103.0
# Index: 53, Value: 115.0
# Index: 54, Value: 15.5
# Index: 55, Value: 116.0
# Index: 56, Value: 117.0
# Index: 57, Value: 110.0
# Index: 58, Value: 67.5
# Index: 59, Value: 102.0
# Index: 60, Value: 40.2
# Index: 61, Value: 96.7
# Index: 62, Value: 66.3
# Index: 63, Value: 87.7
# Index: 64, Value: 37.0
